# %% [markdown]
# # Library Usage Playground

# %% [markdown]
# This Jupyter notebook is simply here to experiment and find any limitations with using AlphaVantage, BackTrader and other tools.

# %% [markdown]
# ## AlphaVantage Usage
# AlphaVantage is a free API for getting historical stock data as well as live prices. This could be useful for backtesting but depending on the communication through brokers, likely won't be used for live trading.

# %%
# Imports 
from alpha_vantage.timeseries import TimeSeries
import json  
import numpy as np 
import pandas as pd
import os 
import matplotlib.pyplot as plt
import backtrader as bt

# %%
# Load the API Key once using the 'secrets' library 
with open('../secrets/secrets.json') as f:
    vals = json.load(f)
    API_KEY = vals['ALPHA_VANTAGE_API_KEY']

# %%
# Input start and end dates
symbol = 'TSLA'
start_date = '2003-01-01'
end_date = '2023-01-01'
ts = TimeSeries(key=API_KEY, output_format='pandas')
# Fetch daily data
data, meta_data = ts.get_daily(
    symbol=symbol,
    outputsize='full'
)

# Convert index to datetime and sort the data
data.index = pd.to_datetime(data.index)
data = data.sort_index(ascending=True)

# Filter data by the provided date range
data = data.loc[start_date:end_date]
data.head()

# Save the final dataframe to CSV
if not os.path.exists('data'):
    os.makedirs('data')
csv_filename = f"data/AAPL_Testing.csv"
data.to_csv(csv_filename)

# %%
# Compute some basic technical indicators 
# Exponential Moving Average (EMA) - 200 Periods
data['EMA_200'] = data['4. close'].ewm(span=200, adjust=False).mean()

# Moving Average Convergence Divergence (MACD)
data['EMA_12'] = data['4. close'].ewm(span=12, adjust=False).mean()
data['EMA_26'] = data['4. close'].ewm(span=26, adjust=False).mean()
data['MACD'] = data['EMA_12'] - data['EMA_26']
data['Signal_Line'] = data['MACD'].ewm(span=9, adjust=False).mean()

data.dropna(inplace=True)
# Save to CSV 
if not os.path.exists('data'):
    os.makedirs('data')
data.to_csv('data/AAPL_Testing.csv')
data.head()
# Out:
#             1. open  2. high  3. low  4. close   5. volume    EMA_200  \
# date
# 2010-06-29    19.00  25.0000   17.54     23.89  18766300.0  23.890000
# 2010-06-30    25.79  30.4192   23.30     23.83  17187100.0  23.889403
# 2010-07-01    25.00  25.9200   20.27     21.96   8218800.0  23.870205
# 2010-07-02    23.00  23.1000   18.71     19.20   5139800.0  23.823735
# 2010-07-06    20.00  20.0000   15.83     16.11   6866900.0  23.746982
#
#                EMA_12     EMA_26      MACD  Signal_Line
# date
# 2010-06-29  23.890000  23.890000  0.000000     0.000000
# 2010-06-30  23.880769  23.885556 -0.004786    -0.000957
# 2010-07-01  23.585266  23.742922 -0.157656    -0.032297
# 2010-07-02  22.910610  23.406409 -0.495799    -0.124997
# 2010-07-06  21.864362  22.865934 -1.001572    -0.300312

# %% [markdown]
# ## Backtrader Usage
# Backtrader is the most popular backtrading framework for testing strategies in Python. We will now attempt to backtest the extremely basic trading strategy where if the EMA(200) is below the current price and the MACD has crossed the Signal Line while both are below 0.

# %%
# 1. Define Custom Data Feed
class MyCSVData(bt.feeds.GenericCSVData):
    lines = ('ema_200', 'ema_12', 'ema_26', 'macd', 'signal_line',)
    params = (
        ('dtformat', '%Y-%m-%d'),  # Only date, no time
        ('datetime', 0),
        ('open', 1),
        ('high', 2),
        ('low', 3),
        ('close', 4),
        ('volume', 5),
        ('openinterest', -1),
        ('ema_200', 6),
        ('ema_12', 7),
        ('ema_26', 8),
        ('macd', 9),
        ('signal_line', 10),
    )

# 2. Define Strategy
class SimpleMACDStrategy(bt.Strategy):
    def __init__(self):
        self.macd = self.datas[0].macd
        self.signal_line = self.datas[0].signal_line
        self.close_price = self.datas[0].close
        self.ema_200 = self.datas[0].ema_200
        self.order = None  # Track pending orders

    def next(self):
        # Check if we have an open order
        if self.order:
            return  # Wait for pending order to complete

        if not self.position:
            if self.macd[0] > self.signal_line[0] and self.ema_200[0] < self.close_price[0] and self.macd[0] < 0 and self.signal_line[0] < 0:  
                cash = self.broker.get_cash()
                size = int(cash / self.close_price[0])
                if size > 0:
                    print(f'Available cash: {cash}, Calculated size: {size}')
                    print('Attempting to BUY')
                    self.order = self.buy(size=size)
        else:
            if self.macd[0] < self.signal_line[0] or self.ema_200[0] > self.close_price[0] or self.macd[0] > 0 or self.signal_line[0] > 0:
                print('Attempting to SELL')
                self.order = self.sell(size=self.position.size)

    def notify_order(self, order):
        if order.status in [order.Completed]:
            if order.isbuy():
                print(f'BUY executed, Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f}')
            elif order.issell():
                print(f'SELL executed, Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f}')
            self.order = None  # Reset order
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            print('Order Canceled/Margin/Rejected')
            self.order = None

# 3. Run Backtest
def run_backtest():
    cerebro = bt.Cerebro()

    data = MyCSVData(dataname='data/AAPL_Testing.csv')

    cerebro.adddata(data)
    cerebro.addstrategy(SimpleMACDStrategy)

    cerebro.broker.setcash(10000.0)
    cerebro.broker.setcommission(commission=0.0)

    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
    cerebro.addanalyzer(bt.analyzers.Returns, _name='returns')

    results = cerebro.run()
    strat = results[0]

    # Results
    print('\n--- Backtest Results ---')
    print(f"Final Portfolio Value: ${cerebro.broker.getvalue():.2f}")
    print(f"Total Return: {(cerebro.broker.getvalue()/10000 - 1)*100:.2f}%")

    sharpe = strat.analyzers.sharpe.get_analysis().get('sharperatio')
    if sharpe is not None:
        print(f"Sharpe Ratio: {sharpe:.2f}")
    else:
        print("Sharpe Ratio: N/A")

    print(f"Max Drawdown: {strat.analyzers.drawdown.get_analysis()['max']['drawdown']:.2f}%")
    print(f"Total Return (From Analyzer): {strat.analyzers.returns.get_analysis()['rnorm100']:.2f}%")

    # Plot
    cerebro.plot(style='candlestick')  # Optional: 'line' or 'candlestick'

# %%
run_backtest()
# Out:
# Available cash: 10000.0, Calculated size: 404
# Attempting to BUY
# BUY executed, Price: 24.63, Cost: 9950.52
# Attempting to SELL
# SELL executed, Price: 23.33, Cost: 9950.52
# Available cash: 9474.8, Calculated size: 379
# Attempting to BUY
# BUY executed, Price: 24.93, Cost: 9448.47
# Attempting to SELL
# SELL executed, Price: 24.44, Cost: 9448.47
# Available cash: 9289.09, Calculated size: 360
# Attempting to BUY
# BUY executed, Price: 24.95, Cost: 8982.00
# Attempting to SELL
# SELL executed, Price: 25.95, Cost: 8982.00
# Available cash: 9649.09, Calculated size: 341
# Attempting to BUY
# Order Canceled/Margin/Rejected
# Available cash: 9649.09, Calculated size: 341
# Attempting to BUY
# Order Canceled/Margin/Rejected
# Available cash: 9649.09, Calculated size: 344
# Attempting to BUY
# Order Canceled/Margin/Rejected
# Available cash: 9649.09, Calculated size: 333
# Attempting to BUY
# BUY executed, Price: 28.50, Cost: 9490.50
# Attempting to SELL
# SELL executed, Price: 29.07, Cost: 9490.50
# Available cash: 9838.9, Calculated size: 296
# Attempting to BUY
# BUY executed, Price: 33.13, Cost: 9806.48
# Attempting to SELL
# SELL executed, Price: 31.96, Cost: 9806.48
# Available cash: 9492.58, Calculated size: 306
# Attempting to BUY
# Order Canceled/Margin/Rejected
# Available cash: 9492.58, Calculated size: 299
# Attempting to BUY
# BUY executed, Price: 31.08, Cost: 9292.92
# Attempting to SELL
# SELL executed, Price: 30.07, Cost: 9292.92
# Available cash: 9190.59, Calculated size: 288
# Attempting to BUY
# Order Canceled/Margin/Rejected
# Available cash: 9190.59, Calculated size: 286
# Attempting to BUY
# Order Canceled/Margin/Rejected
# Available cash: 9190.59, Calculated size: 294
# Attempting to BUY
# BUY executed, Price: 30.75, Cost: 9040.50
# Attempting to SELL
# SELL executed, Price: 29.39, Cost: 9040.50
# Available cash: 8790.75, Calculated size: 286
# Attempting to BUY
# BUY executed, Price: 30.06, Cost: 8597.16
# Attempting to SELL
# SELL executed, Price: 29.57, Cost: 8597.16
# Available cash: 8650.61, Calculated size: 284
# Attempting to BUY
# Order Canceled/Margin/Rejected
# Available cash: 8650.61, Calculated size: 67
# Attempting to BUY
# BUY executed, Price: 126.35, Cost: 8465.45
# Attempting to SELL
# SELL executed, Price: 152.24, Cost: 8465.45
# Available cash: 10385.240000000002, Calculated size: 49
# Attempting to BUY
# BUY executed, Price: 210.81, Cost: 10329.69
# Attempting to SELL
# SELL executed, Price: 198.21, Cost: 10329.69
# Available cash: 9767.840000000002, Calculated size: 47
# Attempting to BUY
# BUY executed, Price: 203.60, Cost: 9569.20
# Attempting to SELL
# SELL executed, Price: 179.86, Cost: 9569.20
# Available cash: 8652.060000000003, Calculated size: 44
# Attempting to BUY
# BUY executed, Price: 196.18, Cost: 8631.92
# Attempting to SELL
# SELL executed, Price: 210.30, Cost: 8631.92
# Available cash: 9273.340000000004, Calculated size: 35
# Attempting to BUY
# BUY executed, Price: 260.10, Cost: 9103.50
# Attempting to SELL
# SELL executed, Price: 238.57, Cost: 9103.50
# Available cash: 8519.790000000003, Calculated size: 36
# Attempting to BUY
# BUY executed, Price: 234.25, Cost: 8433.00
# Attempting to SELL
# SELL executed, Price: 229.60, Cost: 8433.00
# Available cash: 8352.390000000003, Calculated size: 34
# Attempting to BUY
# BUY executed, Price: 241.13, Cost: 8198.42
# Attempting to SELL
# SELL executed, Price: 250.62, Cost: 8198.42
# Available cash: 8675.050000000003, Calculated size: 38
# Attempting to BUY
# BUY executed, Price: 226.90, Cost: 8622.20
# Attempting to SELL
# SELL executed, Price: 223.09, Cost: 8622.20
# Available cash: 8530.270000000002, Calculated size: 33
# Attempting to BUY
# BUY executed, Price: 252.06, Cost: 8317.98
# Attempting to SELL
# SELL executed, Price: 236.00, Cost: 8317.98
# Available cash: 8000.290000000003, Calculated size: 32
# Attempting to BUY
# BUY executed, Price: 245.77, Cost: 7864.64
# Attempting to SELL
# SELL executed, Price: 253.04, Cost: 7864.64
# Available cash: 8232.930000000002, Calculated size: 36
# Attempting to BUY
# BUY executed, Price: 224.99, Cost: 8099.64
# Attempting to SELL
# SELL executed, Price: 219.59, Cost: 8099.64
# Available cash: 8038.530000000002, Calculated size: 34
# Attempting to BUY
# BUY executed, Price: 233.80, Cost: 7949.20
# Attempting to SELL
# SELL executed, Price: 234.98, Cost: 7949.20
# Available cash: 8078.650000000001, Calculated size: 35
# Attempting to BUY
# BUY executed, Price: 224.10, Cost: 7843.50
# Attempting to SELL
# SELL executed, Price: 225.50, Cost: 7843.50
# Available cash: 8127.650000000001, Calculated size: 23
# Attempting to BUY
# BUY executed, Price: 345.00, Cost: 7935.00
# Attempting to SELL
# SELL executed, Price: 318.94, Cost: 7935.00
# Available cash: 7528.27, Calculated size: 21
# Attempting to BUY
# BUY executed, Price: 347.00, Cost: 7287.00
# Attempting to SELL
# SELL executed, Price: 357.53, Cost: 7287.00
# Available cash: 7749.4, Calculated size: 21
# Attempting to BUY
# BUY executed, Price: 352.95, Cost: 7411.95
# Attempting to SELL
# SELL executed, Price: 355.56, Cost: 7411.95
# Available cash: 7804.21, Calculated size: 24
# Attempting to BUY
# BUY executed, Price: 316.77, Cost: 7602.48
# Attempting to SELL
# SELL executed, Price: 313.79, Cost: 7602.48
# Available cash: 7732.690000000001, Calculated size: 24
# Attempting to BUY
# BUY executed, Price: 316.36, Cost: 7592.64
# Attempting to SELL
# SELL executed, Price: 308.56, Cost: 7592.64
# Available cash: 7545.490000000002, Calculated size: 22
# Attempting to BUY
# BUY executed, Price: 330.45, Cost: 7269.90
# Attempting to SELL
# SELL executed, Price: 340.93, Cost: 7269.90
# Available cash: 7776.050000000002, Calculated size: 22
# Attempting to BUY
# BUY executed, Price: 347.83, Cost: 7652.26
# Attempting to SELL
# SELL executed, Price: 353.50, Cost: 7652.26
# Available cash: 7900.790000000003, Calculated size: 22
# Attempting to BUY
# BUY executed, Price: 347.81, Cost: 7651.82
# Attempting to SELL
# SELL executed, Price: 345.46, Cost: 7651.82
# Available cash: 7849.090000000002, Calculated size: 24
# Attempting to BUY
# BUY executed, Price: 308.25, Cost: 7398.00
# Attempting to SELL
# SELL executed, Price: 337.47, Cost: 7398.00
# Available cash: 8550.370000000003, Calculated size: 25
# Attempting to BUY
# BUY executed, Price: 334.40, Cost: 8360.00
# Attempting to SELL
# SELL executed, Price: 344.78, Cost: 8360.00
# Available cash: 8809.870000000003, Calculated size: 27
# Attempting to BUY
# BUY executed, Price: 319.59, Cost: 8628.93
# Attempting to SELL
# SELL executed, Price: 313.30, Cost: 8628.93
# Available cash: 8640.040000000003, Calculated size: 27
# Attempting to BUY
# BUY executed, Price: 306.94, Cost: 8287.38
# Attempting to SELL
# SELL executed, Price: 298.12, Cost: 8287.38
# Available cash: 8401.900000000003, Calculated size: 16
# Attempting to BUY
# BUY executed, Price: 510.26, Cost: 8164.16
# Attempting to SELL
# SELL executed, Price: 742.00, Cost: 8164.16
# Available cash: 12109.740000000003, Calculated size: 11
# Attempting to BUY
# Order Canceled/Margin/Rejected
# Available cash: 12109.740000000003, Calculated size: 11
# Attempting to BUY
# BUY executed, Price: 1098.64, Cost: 12085.04
# Attempting to SELL
# SELL executed, Price: 1061.33, Cost: 12085.04
# Available cash: 11699.330000000002, Calculated size: 12
# Attempting to BUY
# BUY executed, Price: 935.00, Cost: 11220.00
# Attempting to SELL
# SELL executed, Price: 861.57, Cost: 11220.00
# Available cash: 10818.170000000002, Calculated size: 11
# Attempting to BUY
# BUY executed, Price: 914.05, Cost: 10054.55
# Attempting to SELL
# SELL executed, Price: 886.00, Cost: 10054.55
# Available cash: 10509.620000000003, Calculated size: 11
# Attempting to BUY
# BUY executed, Price: 878.77, Cost: 9666.47
# Attempting to SELL
# SELL executed, Price: 849.10, Cost: 9666.47
# Available cash: 10183.250000000004, Calculated size: 11
# Attempting to BUY
# BUY executed, Price: 914.98, Cost: 10064.78
# Attempting to SELL
# SELL executed, Price: 979.94, Cost: 10064.78
#
# --- Backtest Results ---
# Final Portfolio Value: $10897.81
# Total Return: 8.98%
# Sharpe Ratio: 0.04
# Max Drawdown: 27.80%
# Total Return (From Analyzer): 0.69%
# <div id='af287b6b-e7ae-4417-9501-8c5395b9c6a4'></div>

# %% [markdown]
# **Disclaimer: This was not an actual profitable trading strategy, just a test for backtrader**
